# %% [markdown]
# # hi aaron

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
import numpy as np
import matplotlib.pyplot as plt 
import pandas as pd

# %%
pddata_train = pd.read_csv('Data/sign_mnist_test.csv')
data_train = pddata_train.values
data_train_X = data_train[:,1:]
data_train_y = data_train[:,:1]

pddata_test = pd.read_csv('Data/sign_mnist_train.csv')
data_test = pddata_test.values

# %%
print(pddata_train)
# Out:
#       label  pixel1  pixel2  pixel3  pixel4  pixel5  pixel6  pixel7  pixel8  \
# 0         6     149     149     150     150     150     151     151     150
# 1         5     126     128     131     132     133     134     135     135
# 2        10      85      88      92      96     105     123     135     143
# 3         0     203     205     207     206     207     209     210     209
# 4         3     188     191     193     195     199     201     202     203
# ...     ...     ...     ...     ...     ...     ...     ...     ...     ...
# 7167      1     135     119     108     102     105      99      61     103
# 7168     12     157     159     161     164     166     166     171     174
# 7169      2     190     191     190     191     190     190     192     192
# 7170      4     201     205     208     209     214     216     218     223
# 7171      2     173     174     173     174     173     173     175     175
#
# ...

# %%
print(data_train.shape)
# Out:
# (7172, 785)

# %%
a = data_train_X[0].reshape(28,28)
print(a)
# Out:
# [[149 149 150 150 150 151 151 150 151 152 152 152 152 152 153 153 151 152
#   152 153 152 152 151 151 150 150 150 149]
#  [150 150 150 152 152 151 152 152 152 152 152 153 154 153 154 154 153 154
#   153 154 153 153 152 152 152 151 150 151]
#  [150 151 151 152 152 152 153 153 152 152 152 153 154 154 155 155 154 154
#   155 155 155 155 154 153 153 151 151 152]
#  [150 151 151 152 152 152 154 154 154 154 154 153 154 155 156 157 157 156
#   155 156 155 154 154 155 152 154 153 153]
#  [151 152 152 152 154 154 154 154 154 155 157 156 156 156 154 150 146 147
#   146 147 143 137 126 126 142 139 152 154]
#  [152 153 153 154 154 155 154 155 155 154 153 150 144 143 145 139 142 144
#   157 157 147 139 128 119 130 113 147 156]
#  [151 153 153 155 155 156 155 152 145 139 141 141 141 153 153 143 135 137
#   139 133 121 107 101 104 110 127 157 156]
#  [151 152 153 155 155 154 151 146 139 131 130 134 137 132 125 111 101  94
#    95 105 113 122 133 145 153 157 156 156]
# ...

# %%
# plt.gray()
plt.matshow(a)
